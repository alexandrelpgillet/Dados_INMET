# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
#Nome:GOIANIA
#Código Estação: A002
#Latitude: -16.64277777
#Longitude: -49.2202777
#Altitude:727.3
#Situação: Operante
#Data Inicial:2001-05-28
#Data Final: 2024-10-22
#Periodicidade da Medição:Horaria 


Data = pd.read_csv('E:/Dados_INMET/dados_A002_H_2001-05-28_2024-10-22.csv',sep=';')


Data.head()
# Out:
#   Data Medicao  Hora Medicao  PRECIPITACAO TOTAL, HORARIO(mm)  \
# 0   28/05/2001             0                              NaN
# 1   28/05/2001           100                              NaN
# 2   28/05/2001           200                              NaN
# 3   28/05/2001           300                              NaN
# 4   28/05/2001           400                              NaN
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA(mB)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    PRESSAO ATMOSFERICA REDUZIDA NIVEL DO MAR, AUT(mB)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %%
Data.dropna(inplace=True)

# %%
Data.tail()
# Out:
#        Data Medicao  Hora Medicao  PRECIPITACAO TOTAL, HORARIO(mm)  \
# 205158   22/10/2024           600                              0.0
# 205159   22/10/2024           700                              0.0
# 205160   22/10/2024           800                              0.0
# 205161   22/10/2024           900                              0.0
# 205162   22/10/2024          1000                              0.0
#
#         PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA(mB)  \
# 205158                                              932.9
# 205159                                              933.0
# 205160                                              933.4
# 205161                                              933.6
# 205162                                              934.3
#
#         PRESSAO ATMOSFERICA REDUZIDA NIVEL DO MAR, AUT(mB)  \
# 205158                                             1015.6
# 205159                                             1015.7
# ...

# %%
Data["Data Medicao"] = pd.to_datetime(Data["Data Medicao"],dayfirst=True, errors='coerce')

Data = Data[Data["Data Medicao"].dt.year==2023]

# %%
Data
# Out:
#        Data Medicao  Hora Medicao  PRECIPITACAO TOTAL, HORARIO(mm)  \
# 189312   2023-01-01             0                              0.0
# 189313   2023-01-01           100                              0.0
# 189314   2023-01-01           200                              0.0
# 189315   2023-01-01           300                              0.0
# 189316   2023-01-01           400                              0.0
# ...             ...           ...                              ...
# 198067   2023-12-31          1900                              0.0
# 198068   2023-12-31          2000                              0.0
# 198069   2023-12-31          2100                              0.0
# 198070   2023-12-31          2200                              0.0
# 198071   2023-12-31          2300                              0.0
#
#         PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA(mB)  \
# 189312                                              933.2
# ...

# %%
Temp = []
Data_media =[]
Data_desvio_padrao=[]
Data_primeiro_quartil=[]
Data_segundo_quartil=[]
Data_terceiro_quartil=[]
Data_mediana=[]
Data_intervalo_interquartil=[]

for i in range(1,13):
    
    
    aux = Data[Data["Data Medicao"].dt.month==i]
    Temp.append(aux["TEMPERATURA DO AR - BULBO SECO, HORARIA(°C)"])
    
    
    Data_media.append(aux["TEMPERATURA DO AR - BULBO SECO, HORARIA(°C)"].mean())
    Data_desvio_padrao.append(aux["TEMPERATURA DO AR - BULBO SECO, HORARIA(°C)"].std())
    Data_primeiro_quartil.append(aux["TEMPERATURA DO AR - BULBO SECO, HORARIA(°C)"].quantile(0.25))
    Data_segundo_quartil.append(aux["TEMPERATURA DO AR - BULBO SECO, HORARIA(°C)"].quantile(0.50))
    Data_terceiro_quartil.append(aux["TEMPERATURA DO AR - BULBO SECO, HORARIA(°C)"].quantile(0.75))
    Data_mediana.append(aux["TEMPERATURA DO AR - BULBO SECO, HORARIA(°C)"].median())
    Data_intervalo_interquartil.append(aux["TEMPERATURA DO AR - BULBO SECO, HORARIA(°C)"].quantile(0.75)-aux["TEMPERATURA DO AR - BULBO SECO, HORARIA(°C)"].quantile(0.25))

# %%
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']

plt.plot(meses,Data_media, marker='o', linestyle='-', color='blue', label='Média Temperatura Mensal')

plt.title("Média Temperatura Mensal de Goiânia")

plt.xlabel("Meses")
plt.ylabel("Temperatura Mensal")
plt.grid(True)

plt.show()

# %%
plt.boxplot(Temp,vert=True , patch_artist=True)
plt.xlabel('Meses')
plt.ylabel('Temperatura')
plt.title("Boxplot")
plt.grid(True)
plt.show()

# %%
plt.bar(meses, Data_media , color='blue')
plt.title('Média')
plt.xlabel('Meses')
plt.ylabel('Temperatura média')
plt.grid(True)
plt.show()

# %%
plt.bar(meses, Data_mediana, color='blue')
plt.title("Mediana")
plt.xlabel('Meses')
plt.ylabel('Mediana Temperatura')
plt.grid(True)
plt.show()

# %%
plt.bar(meses, Data_desvio_padrao, color='blue')
plt.title("Desvio Padrao")
plt.xlabel('Meses')
plt.ylabel('Desvio Padrão Temperatura')
plt.grid(True)
plt.show()

# %%
plt.bar(meses, Data_intervalo_interquartil, color='blue')
plt.title("Intervalo Interquartia")
plt.xlabel('Meses')
plt.ylabel('Intervalo Interquartil')
plt.grid(True)
plt.show()

# %%
for i in range(12):
    
    print(meses[i]+"\n")
    print("Média de temperatura = "+str(Data_media[i])+"\n")
    print("Mediana da temperatura ="+str(Data_mediana[i])+"\n")
    print("Desvio padrão da temperatura= "+str(Data_desvio_padrao[i])+"\n")
    print("Primeiro Quartil ="+str(Data_primeiro_quartil[i])+"\n")
    print("Segundo Quartil ="+str(Data_segundo_quartil[i])+"\n")
    print("Terceiro Quartil ="+str(Data_terceiro_quartil[i])+"\n")
    print("Intervalo Interquartil ="+str(Data_intervalo_interquartil[i])+"\n")
    
    print("\n\n\n\n")
# Out:
# Jan
#
# Média de temperatura = 23.27314439946019
#
# Mediana da temperatura =22.3
#
# Desvio padrão da temperatura= 3.243029025703139
#
# Primeiro Quartil =20.7
#
# Segundo Quartil =22.3
#
# Terceiro Quartil =25.5
#
# Intervalo Interquartil =4.800000000000001
#
#
#
#
#
#
# Fev
#
# Média de temperatura = 24.647321428571427
#
# Mediana da temperatura =23.2
#
# Desvio padrão da temperatura= 4.005502024194876
#
# Primeiro Quartil =21.2
#
# Segundo Quartil =23.2
#
# Terceiro Quartil =28.1
#
# Intervalo Interquartil =6.900000000000002
#
#
#
#
#
#
# Mar
#
# Média de temperatura = 23.853091397849457
#
# Mediana da temperatura =22.7
#
# Desvio padrão da temperatura= 3.7959837261557765
#
# Primeiro Quartil =21.0
#
# Segundo Quartil =22.7
#
# Terceiro Quartil =26.3
#
# Intervalo Interquartil =5.300000000000001
#
#
#
#
#
#
# Abr
#
# Média de temperatura = 23.5675
#
# Mediana da temperatura =22.5
#
# Desvio padrão da temperatura= 3.7318200021587087
#
# Primeiro Quartil =20.6
#
# ...
